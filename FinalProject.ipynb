# %%
import os
import glob

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np 
import rasterio 
import xarray

# %%
filepath = '/Users/isaiastorres/Desktop/GEOG490/ProjectData/Landsat/'

files2013 = sorted(glob.glob(filepath + 'Landsat2013/*.tiff')) 
files2020 = sorted(glob.glob(filepath + 'Landsat2020/*.tiff')) 
print(files2013)
print(files2020)
# Out:
# ['/Users/isaiastorres/Desktop/GEOG490/ProjectData/Landsat/Landsat2013/LC08_L2SP_043034_20130714_20200912_02_T1_SR_B3.tiff', '/Users/isaiastorres/Desktop/GEOG490/ProjectData/Landsat/Landsat2013/LC08_L2SP_043034_20130714_20200912_02_T1_SR_B4.tiff', '/Users/isaiastorres/Desktop/GEOG490/ProjectData/Landsat/Landsat2013/LC08_L2SP_043034_20130714_20200912_02_T1_SR_B5.tiff']
# ['/Users/isaiastorres/Desktop/GEOG490/ProjectData/Landsat/Landsat2020/LC08_L2SP_043034_20200717_20200911_02_T1_SR_B3.tiff', '/Users/isaiastorres/Desktop/GEOG490/ProjectData/Landsat/Landsat2020/LC08_L2SP_043034_20200717_20200911_02_T1_SR_B4.tiff', '/Users/isaiastorres/Desktop/GEOG490/ProjectData/Landsat/Landsat2020/LC08_L2SP_043034_20200717_20200911_02_T1_SR_B5.tiff']

# %%
list_bands2013 = [] 
for file in files2013:
# Read band
    src = rasterio.open(file) 
    band = src.read(1)
             # Append to list
    list_bands2013.append(band)
         # Convert from list of arrays to n-dimensional array
all_bands2013 = np.dstack(list_bands)

# %%
all_bands_image2013 = np.uint8((all_bands2013 / 65536) * 255)

# %%
# Compute NDVI
np.seterr(divide='ignore', invalid='ignore')
ndvi2013 = np.divide((all_bands2013[:,:,2].astype(float) - all_bands2013[:,:,1].astype(float)), \
                 (all_bands2013[:,:,2].astype(float) + all_bands2013[:,:,1].astype(float)))

# %%
# Plot NDVI image
full_extent = [src.bounds.left, src.bounds.right, src.bounds.bottom, src.bounds.top]

fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(ndvi2013, extent=full_extent)
ax.set_title("NDVI image 2013")
fig.colorbar(im, orientation='vertical')
plt.show()

# %%
# Compute NDWI
np.seterr(divide='ignore', invalid='ignore')
ndwi2013 = np.divide((all_bands2013[:,:,0].astype(float) - all_bands2013[:,:,2].astype(float)), \
                 (all_bands2013[:,:,0].astype(float) + all_bands2013[:,:,2].astype(float)))

# %%
# Plot NDWI image
full_extent = [src.bounds.left, src.bounds.right, src.bounds.bottom, src.bounds.top]

fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(ndwi2013, extent=full_extent)
ax.set_title("NDWI image 2013")
fig.colorbar(im, orientation='vertical')
plt.show()

# %%
list_bands2020 = [] 
for file in files2020:
# Read band
    src = rasterio.open(file) 
    band = src.read(1)
             # Append to list
    list_bands2020.append(band)
         # Convert from list of arrays to n-dimensional array
all_bands2020 = np.dstack(list_bands)

# %%
all_bands_image2020 = np.uint8((all_bands2020 / 65536) * 255)

# %%
# Compute NDVI
np.seterr(divide='ignore', invalid='ignore')
ndvi2020 = np.divide((all_bands2020[:,:,2].astype(float) - all_bands2020[:,:,1].astype(float)), \
                 (all_bands2020[:,:,2].astype(float) + all_bands2020[:,:,1].astype(float)))

# %%
# Plot NDVI image
full_extent = [src.bounds.left, src.bounds.right, src.bounds.bottom, src.bounds.top]

fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(ndvi2020, extent=full_extent)
ax.set_title("NDVI image 2020")
fig.colorbar(im, orientation='vertical')
plt.show()

# %%
# Compute NDWI
np.seterr(divide='ignore', invalid='ignore')
ndwi2020 = np.divide((all_bands2020[:,:,0].astype(float) - all_bands2020[:,:,2].astype(float)), \
                 (all_bands2020[:,:,0].astype(float) + all_bands2020[:,:,2].astype(float)))

# %%
# Plot NDWI image
full_extent = [src.bounds.left, src.bounds.right, src.bounds.bottom, src.bounds.top]

fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(ndwi2020, extent=full_extent)
ax.set_title("NDWI image 2020")
fig.colorbar(im, orientation='vertical')
plt.show()
